# %% [markdown]
# # Tarea individual Machine Learning
#
# El nombre del alumno debe estar en el nombre del notebook a continuación de 'Tarea Individual'.
# <br>
# * Por ejemplo: <strong>Tarea Individual Nombre Apellidos</strong>
# <br>
# * Para cambiar el nombre: pincha en el nombre del notebook (a la derecha del icono 'Jupyter') y añade tu nombre.
# <br>
# <br>
# Una vez se hayan resuelto los ejercicios, por favor, expórtalo a HTML y súbelo al Aula Virtual. Para exportarlo como HTML hay que pinchar en File > Download As > HTML.
# <br>
# <br>
#
# ### Objetivo del notebook
#
# En este notebook vamos a recorrer diferentes algoritmos aprendidos a lo largo del módulo así como funciones y pasos realizados durante las prácticas.
# <br>
# El objetivo de esta tarea es repasar todo lo aprendido, saber aplicarlo y tener una buena ocasión para encontrar nuevas dudas y solucionarlas.
#
# ## Puntuación de la tarea individual
#
# La tarea individual se dividirá en 4 fases:
#  * **1. Regresión: 25 puntos.**
#  * **2. Clasificación: 25 puntos.**
#  * **3. Clustering: 25 puntos.**
#  * **4. Reducción de dimensionalidad: 25 puntos.**
#
# En total son 100 puntos. Cada fase es independiente de la otra, se pueden hacer en el orden que se desee. Cada fase tiene su propio dataset.
#
# ## Proceso a desarrollar.
# En las celdas hay un comentario con lo que hay que hacer en dicha celda. Justo debajo del comentario se puede poner el código que se considere.
#
#
# ## Importante
# Cada ejercicio es independiente, por lo que si estáis bloqueados con algún ejercicio podéis cambiar a otro mientras tanto y trabajarlo. Pero **es muy importante saber que si vais a trabajar en un ejercicio, debéis ejecutar las celdas desde el inicio de dicho ejercicio**. Por ejemplo: empiezo con Regresión pero hay algo que no me sale, por lo que lo dejo parado un rato y me pongo con clasificación. Poniendome con clasificación ejecuto la carga del dataframe y me pongo a trabajar. Entonces me doy cuenta de que puedo solucionar algo en regresion, y vuelvo al ejercicio para arreglarlo. **En ese punto, debes volver a ejecutar las celdas desde el principio de regresión hasta llegar a la celda en la que vas a meter código**.
#  Esto se debe hacer para que las variables que estés utilizando en los diferentes ejercicios, si se llaman igual, vuelvan a coger los datos correspondientes a ese ejercicio (si empiezo con regresión 'dt' tendrá los datos de regresión, si paso a clasificación debo meter los datos de clasificación a 'dt' cuando cargo el archivo, y si vuelvo a regresión debo ejecutar regresión desde el inicio para que 'dt', y más variables si se da el caso, vuelvan a tener los datos de regresión).

# %% [markdown]
# ##### Estas son las librerías que son necesarias para ejecutar todo el notebook.
# * pandas
# * matplotlib
# * scikit learn
# * seaborn
#
# Ninguna más sería necesaria para completar la tarea siguiendo las prácticas, aún así, si se necesita añadir alguna por favor añadidla aquí.
# Si faltara alguna librería por ejemplo seaborn se podría instalar metiendo una celda
# `!pip install seaborn`
#
# ##  0 - Carga de Librerías

# %%
import warnings
warnings.filterwarnings(action="ignore")

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np

from matplotlib import pyplot as plt
from matplotlib.ticker import FixedLocator, FixedFormatter
import seaborn as sns
from scipy.stats import pearsonr
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import silhouette_score
from sklearn.metrics import silhouette_samples

# %% [markdown]
# # 1. Regresión xG - Puntos
#
# La dirección deportiva de un club de fútbol nos ha pedido desarrollar un modelo para predecir, en base a los xG de su equipo en la temporada, cuantos puntos tiene. Así, teniendo un histórico de equipos con su xG en la temporada y los puntos que obtuvieron, podemos sacar una serie de conclusiones: si hay cierta relación entre que un equipo sea muy atacante y los puntos que obtiene y si a final de temporada el propio club ha estado mejor o peor de lo que se debería en relación al xG vs Puntos.
#
# <br>
# <strong>
#     Para seguir estos pasos, se recomienda ir paso a paso en el notebook 'CRISP-DM: Regresión'
# </strong>

# %% [markdown]
# ### 1.1 Estudio de los datos (5 puntos)

# %%
# Cargamos el dataset (en la carpeta data con nombre Regresion)
dt = pd.read_csv('data/Regresion.csv')

# %%
# Visualizar las 5 primeras muestras del dataset
dt.head(5)
# Out:
#         TeamName     Season  xG_Season  Goles_Season  Points
# 0  Villarreal CF  2017-2018       52.1            57      61
# 1  Villarreal CF  2018-2019       50.5            49      44
# 2    Valencia CF  2017-2018       55.9            65      73
# 3    Valencia CF  2018-2019       57.3            51      61
# 4  UD Las Palmas  2017-2018       37.8            24      22

# %%
# Visualizar los tipos de datos de cada variable
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TeamName      40 non-null     object
#  1   Season        40 non-null     object
#  2   xG_Season     40 non-null     float64
#  3   Goles_Season  40 non-null     int64
#  4   Points        40 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.7+ KB

# %%
# Visualizar los parámetros estadísticos del dataset
dt.describe()
# Out:
#        xG_Season  Goles_Season     Points
# count  40.000000     40.000000  40.000000
# mean   48.862500     50.175000  52.100000
# std    11.005516     16.397135  16.014096
# min    33.300000     24.000000  20.000000
# 25%    40.875000     40.750000  43.750000
# 50%    46.550000     47.000000  50.000000
# 75%    51.800000     58.250000  59.250000
# max    83.400000     99.000000  93.000000

# %%
# Visualizar los histogramas del dataset
sns.pairplot(dt[['xG_Season', 'Goles_Season', 'Points']])

# %% [markdown]
# ### 1.2 Aplicación de algoritmo (10 puntos)

# %%
# Obtener dos set de datos: un set de train y otro de test.
# Fijar el tamaño del set de test en un 20% (0.2)
size = 0.2
train_set, test_set = train_test_split(dt, test_size=size, random_state=42)

# %%
# Obtener la matriz de correlación frente a la variable que queremos predecir (Points)
corr_matrix = train_set.corr()
corr_matrix['Points'].sort_values(ascending=False)
# Out:
# Points          1.000000
# Goles_Season    0.783587
# xG_Season       0.710175
# Name: Points, dtype: float64

# %%
corr_test = pearsonr(x = train_set['xG_Season'], y =  train_set['Points'])
print("Coeficiente de correlación de Pearson: %.6f" % corr_test[0])
print("P-value: %.7f " % corr_test[1])
# Out:
# Coeficiente de correlación de Pearson: 0.710175
# P-value: 0.0000053

# %%
# Mostrar las correlaciones mediante un heatmap en el set de train
corr_matrix = train_set.corr()
heatmap = sns.heatmap(corr_matrix, annot=True)
heatmap.set(ylim=(0,len(corr_matrix)))
heatmap.set(xlim=(0,len(corr_matrix)))

plt.show()

# %%
lst=["Goles_Season", 'xG_Season']
fig, ax= plt.subplots(figsize=(8, 6))
#[ax.train_set.plot(kind="scatter", x=i, y="Points", alpha=0.5) for i in lst]
[ax.scatter(train_set[i], train_set["Points"],  alpha=0.5, label=i) for i in lst]
ax.legend()

# %%
# Coger sólo las columnas xG_Season (feature) y Points (label) del set de train
# Como se ha hecho en PreparingData_v2 pero con train_set en lugar de dt.
train_set=train_set[['xG_Season', 'Points']]

# %%
# Escalar la columna xG_Season en el set de train (StandardScaler)
# Como se ha hecho en PreparingData (Standarization) pero solo con xG_Season en lugar de Goals y Year
train_set[['xG_Season_std']] = StandardScaler().fit_transform(train_set[['xG_Season']])
train_set=train_set.drop(['xG_Season'], axis=1)

# %%
# Separar el set de train en features y labels. Vamos a trabajar con dos variables: labels es Points y features es xG_Season.
# Como se ha hecho en splitDT pero poniendo 'Points' en lugar de label, cambiando train_set por dt y llamando
# a labels y_train y a features X_train
def splitDT(dt, label):
    labels = dt[[label]]
    features = dt.drop([label], axis=1)

    return features, labels

# %%
X_train, y_train = splitDT(train_set, 'Points')
X_train
# Out:
#     xG_Season_std
# 39      -0.847926
# 6        1.375367
# 25      -0.242434
# 9        0.154921
# 13       3.248609
# 31      -1.112829
# 34      -0.876308
# 8       -0.847926
# 17      -0.583023
# 24      -0.989838
# 0        0.287372
# 33      -0.412728
# 5        0.741492
# 11       0.552275
# 1        0.135999
# 29       0.003548
# 21      -0.649249
# 2        0.646884
# 30      -0.961456
# 36      -0.138364
# 3        0.779335
# 35      -1.103368
# 23      -0.034295
# 32       0.249529
# 10      -0.810083
# 22       0.079234
# 18      -0.034295
# 20      -1.491262
# 7       -0.289738
# 14       1.195611
# 28       2.321449
# 38      -0.346503

# %% [markdown]
# ### 3 funciones auxiliares en estado final

# %%
def Display_Score(labels, predictions):
    mse = mean_squared_error(labels, predictions)
    rmse = np.sqrt(mse)
    print("No Cross Validation")
    print("RMSE Score: ", rmse)
    print("----------")
    
def Display_CV_Scores(scores):
    rmse_scores = np.sqrt(-scores)
    print("Cross Validation")
    print("RMSE Scores:", rmse_scores)
    print("RMSE Mean:", rmse_scores.mean())
    print("RMSE Standard deviation:", rmse_scores.std())
    
def VisualizeRegression(X, y, pred):
    
    X = X.loc[:, [X.columns[0]]]
    y = y.loc[:, [y.columns[0]]]

    inds = X.values.ravel().argsort()
    X = X.values.ravel()[inds].reshape(-1,1)
    y = y.values[inds]
    pred = pred[inds]
    
    fig, ax =  plt.subplots(figsize=(8, 6))
    ax.scatter(X, y,  color='blue', marker='.',)
    ax.plot(X, pred, color='red', label="Predictions")
    ax.set_title("xG_Season vs Points")
    ax.set_xlabel("xG_Season (after StandardScaler)")
    ax.set_ylabel("Points")
    plt.show()

# %%
#####################
# Aplicar Linear Regression. Usar las funciones para ello.
#####################

# Entrenamos el modelo
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)

# Predicciones en el set de entrenamiento
lin_reg_pred = lin_reg.predict(X_train)

# Métricas obtenidas sin CV
Display_Score(y_train, lin_reg_pred)

# Métricas obtenidas con CV
lin_reg_cv = LinearRegression()
lin_reg_cv_scores = cross_val_score(lin_reg_cv, X_train, y_train, scoring="neg_mean_squared_error", cv=10)
Display_CV_Scores(lin_reg_cv_scores)

# Visualizacion
VisualizeRegression(X_train, y_train, lin_reg_pred)
# Out:
# No Cross Validation
# RMSE Score:  9.885288955478003
# ----------
# Cross Validation
# RMSE Scores: [ 7.72146431 11.15535972  5.23024075  6.22755021 14.61344666 20.68159388
#   3.15447183  6.06413303 14.6975283  10.85166912]
# RMSE Mean: 10.03974577873713
# RMSE Standard deviation: 5.138263514961002

# %% [markdown]
# ### 1.3 Evaluando el algoritmo (10 puntos)

# %%
# Coger sólo las columnas xG_Season (feature) y Points (label) del set de test
# Como se ha hecho en PreparingData_v2 pero con test_set en lugar de dt.
test_set=test_set[['xG_Season', 'Points']]

# %%
# Escalar la columna xG_Season en el set de test (StandardScaler)
# Como se ha hecho en PreparingData (Standarization) pero solo con xG_Season en lugar de Goals y Year
test_set['xG_Season_std']=StandardScaler().fit_transform(test_set[['xG_Season']])
test_set=test_set.drop(['xG_Season'], axis=1)

# %%
# Separar el set de test en features y labels. Vamos a trabajar con dos variables: labels es Points y features es xG_Season.
# Como se ha hecho en splitDT pero poniendo 'Points' en lugar de label, cambiando test_set por dt y llamando
# a labels y_test y a features X_test
X_test, y_test = splitDT(test_set, 'Points')

# %%
# Predicciones en el set de test
final_predictions = lin_reg.predict(X_test)

# Las métricas obtenidas en el test set (RMSE)

Display_Score(y_test, final_predictions)

# Métricas obtenidas con CV
lin_reg_cv = LinearRegression()
lin_reg_cv_scores = cross_val_score(lin_reg_cv, X_test, y_test, scoring="neg_mean_squared_error", cv=8)
Display_CV_Scores(lin_reg_cv_scores)

# Visualizacion
VisualizeRegression(X_test, y_test, final_predictions)
# Out:
# No Cross Validation
# RMSE Score:  15.44201823073399
# ----------
# Cross Validation
# RMSE Scores: [16.49705425  7.31320262 17.32390777  9.48231786 24.55931071  3.72372742
#  27.21920136 53.60582153]
# RMSE Mean: 19.965567937899667
# RMSE Standard deviation: 14.824690348951831

# %% [markdown]
# ### La regresión no es muy buena ya que esta es perturbada por un outlier y la pequeña cantidad de datos del set de pruebas. Es por ello que la recta no predice muy bien los valores introducidos. Para mejorar este ajuste convendría introducir una mayor muestra tanto de entrenamiento como de prueba.

# %% [markdown]
# Red neuronal

# %%
oculta1=tf.keras.layers.Dense(units=3, input_shape=[1])
oculta2=tf.keras.layers.Dense(units=3)
salida=tf.keras.layers.Dense(units=1)
modelo=tf.keras.Sequential([oculta1, oculta2, salida])

# %%
modelo.compile(optimizer=tf.keras.optimizers.Adam(0.1), loss='mean_squared_error')

# %%
print('Comenzando el entrenamiento...')
historial = modelo.fit(X_train, y_train, epochs=80, verbose=False)

print('Entrenado')
# Out:
# Comenzando el entrenamiento...
# Entrenado

# %%
plt.xlabel('Época')
plt.ylabel('Magnitud de perdidas')
plt.plot(historial.history['loss'])

# %%
resultado_train=modelo.predict(X_train)
fig, ax =  plt.subplots(figsize=(8, 6))
ax.scatter(X_train, y_train,  color='blue', marker='.',)
ax.plot(X_train, resultado_train, color='red', label="Predictions")

Display_Score(y_train, resultado_train)
# Out:
# 1/1 [==============================] - 0s 103ms/step
# No Cross Validation
# RMSE Score:  9.912137830698748
# ----------

# %%
print('Hacemos una predicción')
resultado_test=modelo.predict(X_test)
fig, ax =  plt.subplots(figsize=(8, 6))
ax.scatter(X_test, y_test,  color='blue', marker='.',)
ax.plot(X_test, resultado_test, color='red', label="Predictions")
# Out:
# Hacemos una predicción
# 1/1 [==============================] - 0s 106ms/step

# %% [markdown]
# ### Se ha intentado un modelo simple de red neuronal para comparar resultados, siendo bastante mejor la regresión

# %% [markdown]
# # 2. Clasificación - 10 primeros Liga
#
# La dirección deportiva de un club de fútbol español nos ha pedido desarrollar un modelo de machine learning con el que podamos **predecir si un equipo va a quedar entre los diez primeros o no**, o lo que es lo mismo, en la primera mitad de la clasificación. La idea que tienen es que si se tiene un histórico de datos y se puede predecir si un equipo estará entre los mejores o no en base a su performance en esa temporada, podrían sacar conclusiones antes de final de temporada y anticiparse a lo que está por venir.
#
# Nos comentan en la reunión que el histórico de partidos se refiere a la temporada 17/18 y a las principales ligas europeas: España, Italia, Alemania, Francia e Inglaterra.
# Nos comentan que el dataset tiene como datos el nombre del equipo, la competición, la temporada, el xG, el xA (expected assitances), la posición y si el equipo estuvo en la primera mitad o en la segunda. Este análisis lo hacen porque les interesa mucho saber si el ser muy atacante así como con juego colaborativo hace tender a un equipo a estar entre los mejores.
#
# <br>
# <strong>
#     Para seguir estos pasos, se recomienda ir paso a paso en el notebook 'CRISP-DM: Clasificación'
# </strong>

# %% [markdown]
# ### 2.1 Estudio de los datos (5 puntos)

# %%
# Cargamos el dataset (en la carpeta data con nombre Clasificacion)
dt = pd.read_csv('data/Clasificacion.csv')

# %%
# Visualizar las 5 primeras muestras del dataset
dt.head(5)
# Out:
#           TeamName            CompName     Season    xG    xA Position  \
# 0       1. FC Köln  Fußball-Bundesliga  2017-2018  42.6  28.7      18°
# 1  1. FSV Mainz 05  Fußball-Bundesliga  2017-2018  35.2  24.3      14°
# 2  AC ChievoVerona             Serie A  2017-2018  32.4  22.1      13°
# 3         AC Milan             Serie A  2017-2018  55.9  36.3       6°
# 4   ACF Fiorentina             Serie A  2017-2018  58.3  37.1       8°
#
#    Best_Teams
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1

# %%
# Visualizar los tipos de datos de cada variable
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TeamName    98 non-null     object
#  1   CompName    98 non-null     object
#  2   Season      98 non-null     object
#  3   xG          98 non-null     float64
#  4   xA          98 non-null     float64
#  5   Position    98 non-null     object
#  6   Best_Teams  98 non-null     int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 5.5+ KB

# %%
# Visualizar los parámetros estadísticos del dataset
dt.describe()
# Out:
#                xG         xA  Best_Teams
# count   98.000000  98.000000   98.000000
# mean    51.538776  34.398980    0.500000
# std     16.340763  11.883875    0.502571
# min     31.400000  18.300000    0.000000
# 25%     40.300000  26.150000    0.000000
# 50%     46.100000  30.550000    0.500000
# 75%     57.950000  39.825000    1.000000
# max    106.600000  77.600000    1.000000

# %%
# Visualizar los histogramas del dataset
#dt.hist(bins=50, figsize=(18, 3), layout=(1, 3))
sns.pairplot(dt[['xG', 'xA', 'Best_Teams']])

# %% [markdown]
# ### 2.2 Aplicación de algoritmo (10 puntos)

# %%
# Obtener dos set de datos: un set de train y otro de test.
# Fijar el tamaño del set de test en un 20% (0.2)
size = 0.2
train_set, test_set = train_test_split(dt, test_size=size, random_state=42)

# %%
# Obtener la matriz de correlación frente a la variable que queremos predecir (Best_Teams) en el set de train
corr_matrix = train_set.corr()
corr_matrix['Best_Teams'].sort_values(ascending=False)
# Out:
# Best_Teams    1.000000
# xA            0.548653
# xG            0.541883
# Name: Best_Teams, dtype: float64

# %%
# Copiamos el set porque esto va a ser una prueba rápida y no quiero ensuciar el train_set con la nueva columna
temp = train_set.copy()
temp['Position'] = pd.to_numeric(temp['Position'].str.replace('°',''))
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78 entries, 49 to 51
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TeamName    78 non-null     object
#  1   CompName    78 non-null     object
#  2   Season      78 non-null     object
#  3   xG          78 non-null     float64
#  4   xA          78 non-null     float64
#  5   Position    78 non-null     int64
#  6   Best_Teams  78 non-null     int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 4.9+ KB

# %%
# Mostrar las correlaciones mediante un heatmap en el set de train
corr_matrix = train_set.corr()
heatmap = sns.heatmap(corr_matrix, annot=True)
heatmap.set(ylim=(0,len(corr_matrix)))
heatmap.set(xlim=(0,len(corr_matrix)))

plt.show()

# %%
# Coger sólo las columnas xG, xA (features) y Best_Teams (label) del set de train

# Creamos dos datasets, cada uno para su mitad.
Mitad_1 = train_set[train_set['Best_Teams']==1]
Mitad_0 = train_set[train_set['Best_Teams']==0]

# Mostramos los dos datasets: en rojo los 10 peores y en azul los 10 mejores
plt.scatter(Mitad_1['xG'], Mitad_1['xA'], marker='o', color='b')
plt.scatter(Mitad_0['xG'], Mitad_0['xA'], marker='o', color='r')

# Ponemos los ejes
plt.xlabel("xG")
plt.ylabel("xA")

# Escribimos la leyenda (qué épico suena)
plt.legend(('Primera mitad de la tabla', 'Segunda mitad de la tabla'), scatterpoints=1, loc='upper right', ncol=1, fontsize=8)

# %%
def PreparingData(dt):
    
    # Categorizo las columnas de dt que lo requieran con one-hot
    dt = pd.get_dummies(dt, columns=['TeamName', 'CompName'])
    
    # Categorizo a ordinal
    dt = dt.replace({'2017-2018':1})
    
    # Data cleaning
    dt = dt.drop(['Position', 'Season'], axis=1)
    
    # Standarization
    dt[['xG', 'xA']] = StandardScaler().fit_transform(dt[['xG', 'xA']])
    
    return dt

# %%
# Escalar la columna xG y xA en el set de train (StandardScaler)
# Como se ha hecho en PreparingData (Standarization) pero con xG y xA en lugar de Goals y Goals_Against
train_set_prep = PreparingData(train_set)
train_set_prep.head()
# Out:
#           xG        xA  Best_Teams  TeamName_1. FSV Mainz 05  \
# 49  0.603416  0.803222           1                         0
# 70  1.884886  1.131365           0                         0
# 68  1.908080  2.011749           1                         0
# 15  0.487446  0.747197           1                         0
# 39 -0.417121 -0.453326           1                         0
#
#     TeamName_AC ChievoVerona  TeamName_AC Milan  TeamName_AFC Bournemouth  \
# 49                         0                  0                         0
# 70                         0                  0                         0
# 68                         0                  0                         0
# 15                         0                  0                         0
#     CompName_Premier League  CompName_Serie A
# 49                        0                 1
# 70                        0                 0
# 68                        0                 0
# 15                        0                 0
# 39                        0                 0

# %%
corr_matrix = train_set_prep.corr()
corr_matrix['Best_Teams'].sort_values(ascending=False)
# Out:
# Best_Teams                            1.000000
# xA                                    0.548653
# xG                                    0.541883
# TeamName_Newcastle United FC          0.116921
# TeamName_Paris Saint-Germain FC       0.116921
# TeamName_OGC Nice                     0.116921
# TeamName_Leicester City FC            0.116921
# TeamName_Stade Rennais FC             0.116921
# TeamName_Manchester United FC         0.116921
# TeamName_Juventus FC                  0.116921
# TeamName_Girona FC                    0.116921
# TeamName_Burnley FC                   0.116921
# TeamName_Olympique de Marseille       0.116921
# TeamName_FC Girondins de Bordeaux     0.116921
# TeamName_Real Betis                   0.116921
# TeamName_Everton FC                   0.116921
# TeamName_SD Eibar                     0.116921
# TeamName_SSC Napoli                   0.116921
# TeamName_Liverpool FC                 0.116921
# TeamName_Chelsea FC                   0.116921
# TeamName_TSG 1899 Hoffenheim          0.116921
# TeamName_Atlético Madrid              0.116921
# TeamName_AC Milan                     0.116921
# TeamName_VfB Stuttgart                0.116921
# TeamName_Valencia CF                  0.116921
# TeamName_Arsenal FC                   0.116921
# TeamName_UC Sampdoria                 0.116921
# TeamName_Torino FC                    0.116921
# TeamName_Eintracht Frankfurt          0.116921
# TeamName_Bayer 04 Leverkusen          0.116921
# TeamName_Internazionale               0.116921
# TeamName_Montpellier HSC              0.116921
# TeamName_AS Monaco FC                 0.116921
# TeamName_AS Saint-Étienne             0.116921
# TeamName_Manchester City FC           0.116921
# TeamName_FC Nantes                    0.116921
# TeamName_FC Bayern Munich             0.116921
# TeamName_FC Barcelona                 0.116921
# TeamName_Real Madrid CF               0.116921
# TeamName_Sevilla FC                   0.116921
# TeamName_Borussia Mönchengladbach     0.116921
# CompName_Premier League               0.076551
# CompName_Ligue 1                      0.014049
# CompName_Fußball-Bundesliga           0.010937
# CompName_La Liga                     -0.046829
# CompName_Serie A                     -0.054841
# TeamName_Lille OSC                   -0.111075
# TeamName_Celta de Vigo               -0.111075
# TeamName_1. FSV Mainz 05             -0.111075
# TeamName_AC ChievoVerona             -0.111075
# TeamName_Amiens SC                   -0.111075
# TeamName_West Bromwich Albion FC     -0.111075
# TeamName_Watford FC                  -0.111075
# TeamName_Athletic Club               -0.111075
# TeamName_Udinese Calcio              -0.111075
# TeamName_Benevento Calcio            -0.111075
# TeamName_Troyes AC                   -0.111075
# TeamName_Toulouse FC                 -0.111075
# TeamName_Bologna FC 1909             -0.111075
# TeamName_Brighton & Hove Albion FC   -0.111075
# TeamName_Huddersfield Town AFC       -0.111075
# TeamName_CD Leganés                  -0.111075
# TeamName_Levante UD                  -0.111075
# TeamName_RCD Espanyol                -0.111075
# TeamName_Hellas Verona FC            -0.111075
# TeamName_FC Crotone                  -0.111075
# TeamName_Dijon FCO                   -0.111075
# TeamName_Genoa CFC                   -0.111075
# TeamName_FC Metz                     -0.111075
# TeamName_AFC Bournemouth             -0.111075
# TeamName_SV Werder Bremen            -0.111075
# TeamName_UD Las Palmas               -0.111075
# TeamName_FC Augsburg                 -0.111075
# TeamName_Hannover 96                 -0.111075
# TeamName_Real Sociedad               -0.111075
# TeamName_Stade Malherbe Caen         -0.111075
# TeamName_SPAL 2013                   -0.111075
# TeamName_Málaga CF                   -0.111075
# TeamName_Angers SCO                  -0.111075
# TeamName_Stoke City FC               -0.111075
# TeamName_West Ham United FC          -0.111075
# TeamName_Deportivo Alavés            -0.111075
# TeamName_VfL Wolfsburg               -0.111075
# TeamName_Deportivo de La Coruña      -0.111075
# TeamName_RC Strasbourg Alsace        -0.111075
# TeamName_SC Freiburg                 -0.111075
# Name: Best_Teams, dtype: float64

# %%
def splitDT(dt, label):
    labels = dt[[label]]
    features = dt.drop([label], axis=1)

    return features, labels

# %%
# Separar el set de train en features y labels. Vamos a trabajar con dos variables: labels es Best_Teams y features son xG y xA.

# a labels y_train y a features X_train
train_set=train_set[['xG', 'xA', 'Best_Teams']]

X_train, y_train = splitDT(train_set, 'Best_Teams')

# %% [markdown]
# ### 3 funciones auxiliares en estado final

# %%
def Display_Score(labels, predictions):
    acc = accuracy_score(labels, predictions)
    print("No Cross Validation")
    print("Accuracy Score: ", acc)
    print("----------")
    
def Display_CV_Scores(scores):
    print("Cross Validation")
    print("Accuracy Scores:", scores)
    print("Accuracy Mean:", scores.mean())
    print("Accuracy Standard deviation:", scores.std())
    
def VisualizeConfusionMatrix(X, y, pred):
    
    cm = confusion_matrix(y, pred)
    
    df_cm = pd.DataFrame(cm, columns=np.unique(y), index = np.unique(y))
    df_cm.index.name = 'Actual'
    df_cm.columns.name = 'Predicted'
    
    plt.figure(figsize = (6,4))

    heatmap = sns.heatmap(df_cm, cmap="Blues", annot=True, fmt='g')
    heatmap.set(ylim=(0,len(df_cm)))
    heatmap.set(xlim=(0,len(df_cm)))

# %%
#####################
# Aplicar Logistic Regression. Usar las funciones para ello.
#####################

# Entrenamos el modelo
lr = LogisticRegression(random_state=42)
lr.fit(X_train, y_train)

# Predicciones en el set de entrenamiento
lr_pred = lr.predict(X_train)

# Métricas obtenidas sin CV
Display_Score(y_train, lr_pred)

# Métricas obtenidas con CV
lr_cv = LogisticRegression(random_state=42)
lr_cv_scores = cross_val_score(lr_cv, X_train, y_train, scoring="accuracy", cv=10)
Display_CV_Scores(lr_cv_scores)

# Visualizacion
VisualizeConfusionMatrix(X_train, y_train, lr_pred)
# Out:
# No Cross Validation
# Accuracy Score:  0.7948717948717948
# ----------
# Cross Validation
# Accuracy Scores: [0.75       0.75       0.75       0.875      0.75       0.75
#  0.75       0.875      0.85714286 0.57142857]
# Accuracy Mean: 0.7678571428571428
# Accuracy Standard deviation: 0.08451542547285165

# %% [markdown]
# ## 2.3 Evaluando el algoritmo (10 puntos)

# %%
# Escalar la columna xG y xA en el set de test (StandardScaler)
# Como se ha hecho en PreparingData (Standarization) pero con xG y xA en lugar de Goals y Goals_Against
test_set_prep = PreparingData(test_set)
test_set_prep.head()
# Out:
#           xG        xA  Best_Teams  TeamName_1. FC Köln  \
# 62  1.313666  1.279369           1                    0
# 40 -0.371075 -0.406577           1                    0
# 94  0.000432  0.510945           1                    0
# 18  1.140872  1.049988           1                    0
# 81 -1.822545 -1.817266           0                    0
#
#     TeamName_ACF Fiorentina  TeamName_AS Roma  TeamName_Atalanta BC  \
# 62                        0                 0                     0
# 40                        0                 0                     0
# 94                        0                 0                     0
# 18                        0                 0                     0
# 81                        0                 0                     0
#
#     TeamName_Borussia Dortmund  TeamName_Cagliari Calcio  \
# 62                           0                         0
# 40                           0                         0
# 94                           0                         0
# 18                           1                         0
# 81                           0                         0
#
#     TeamName_Crystal Palace FC  TeamName_En Avant de Guingamp  \
# 62                           0                              0
# 40                           0                              0
# 94                           0                              0
# 18                           0                              0
# 81                           0                              0
#
#     TeamName_FC Schalke 04  TeamName_Getafe CF  TeamName_Hamburger SV  \
# 62                       0                   0                      0
# 40                       1                   0                      0
# 94                       0                   0                      0
# 18                       0                   0                      0
# 81                       0                   0                      0
#
#     TeamName_Hertha BSC  TeamName_Olympique Lyonnais  TeamName_RB Leipzig  \
# 62                    0                            1                    0
# 40                    0                            0                    0
# 94                    0                            0                    0
# 18                    0                            0                    0
# 81                    0                            0                    0
#
#     TeamName_SS Lazio  TeamName_Southampton FC  TeamName_Swansea City AFC  \
# 62                  0                        0                          0
# 40                  0                        0                          0
# 94                  0                        0                          0
# 18                  0                        0                          0
# 81                  0                        0                          1
#
#     TeamName_Tottenham Hotspur FC  TeamName_US Sassuolo Calcio  \
# 62                              0                            0
# 40                              0                            0
# 94                              0                            0
# 18                              0                            0
# 81                              0                            0
#
#     TeamName_Villarreal CF  CompName_Fußball-Bundesliga  CompName_La Liga  \
# 62                       0                            0                 0
# 40                       0                            1                 0
# 94                       1                            0                 1
# 18                       0                            1                 0
# 81                       0                            0                 0
#
#     CompName_Ligue 1  CompName_Premier League  CompName_Serie A
# 62                 1                        0                 0
# 40                 0                        0                 0
# 94                 0                        0                 0
# 18                 0                        0                 0
# 81                 0                        1                 0

# %%
# Coger sólo las columnas xG y xA (features) y Best_Teams (label) del set de test
# Como se ha hecho en PreparingData_v2 pero con test_set en lugar de dt.
test_set=test_set_prep[['xG', 'xA', 'Best_Teams']]
test_set.head()
# Out:
#           xG        xA  Best_Teams
# 62  1.313666  1.279369           1
# 40 -0.371075 -0.406577           1
# 94  0.000432  0.510945           1
# 18  1.140872  1.049988           1
# 81 -1.822545 -1.817266           0

# %%
# Separar el set de test en features y labels
# Como se ha hecho en splitDT pero poniendo 'Best_Teams' en lugar de label, cambiando test_set por dt y llamando
# a labels y_test y a features X_test
X_test, y_test= splitDT(test_set, 'Best_Teams')

# %%
# Predicciones en el set de test
final_predictions = lr.predict(X_test)
# Las métricas obtenidas en el test set (Accuracy)
acc = accuracy_score(y_test, final_predictions)
print("Accuracy Score: ", acc)
# Visualizacion
VisualizeConfusionMatrix(X_test, y_test, final_predictions)
# Out:
# Accuracy Score:  0.45

# %% [markdown]
# ### El modelo no se comporta correctamente, esto se ve en que existe un valor muy alto de imprecisión con el set de prueba. Ampliando el data set posiblemente la presición del modelo mejore.

# %% [markdown]
# # 3. Clustering Delanteros
#
# El club deportivo para el que trabajamos nos han comentado la necesidad de **buscar a un delantero centro interesante** en el mercado. Nos han pedido ayuda para intentar conocer mejor los delanteros centro que hay disponibles y poder agruparlos, de este modo poder conocer mejor cuales se parecen entre ellos y tener unas conclusiones más interesantes antes de ir al mercado.
# Si nos interesa un jugador concreto, podemos buscar similares a ver si nos parecen igual de interesante y surge una oportunidad.
#
# <br>
# <strong>
#     Para seguir estos pasos, se recomienda ir paso a paso en el notebook 'Clustering: Data Analysis'
# </strong>

# %% [markdown]
# ### 3.1 Estudio de los datos (5 puntos)

# %%
# Cargamos el dataset (en la carpeta data con nombre Clustering)
dt = pd.read_csv('data/Clustering.csv')

# %%
# Visualizar las 5 primeras muestras del dataset
dt.head(5)
# Out:
#           PlayerName                TeamName     Season  Gol/Sh  npxG/Sh
# 0      Erling Håland       Borussia Dortmund  2019-2020    0.37     0.23
# 1       Mauro Icardi  Paris Saint-Germain FC  2019-2020    0.33     0.28
# 2       Jadon Sancho       Borussia Dortmund  2019-2020    0.33     0.18
# 3  Andreas Cornelius                Parma FC  2019-2020    0.27     0.16
# 4         Ante Rebic                AC Milan  2019-2020    0.26     0.17

# %%
# Visualizar los tipos de datos de cada variable
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PlayerName  93 non-null     object
#  1   TeamName    93 non-null     object
#  2   Season      93 non-null     object
#  3   Gol/Sh      93 non-null     float64
#  4   npxG/Sh     93 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 3.8+ KB

# %%
# Escalar las variables Gol/Sh y npxG/Sh
# Recomendación: como hacemos en el notebook, crea unas variables (std) y luego escala.
dt['Gol/Sh_std'] = dt['Gol/Sh']
dt['npxG/Sh_std'] = dt['npxG/Sh']

dt[['Gol/Sh_std', 'npxG/Sh_std']] = StandardScaler().fit_transform(dt[['Gol/Sh', 'npxG/Sh']])

# %%
# Visualizamos los datos
X = dt[['Gol/Sh_std', 'npxG/Sh_std']].values
plt.figure(figsize=(16, 8))
plt.scatter(X[:, 0], X[:, 1], c=None, s=20)
plt.xlabel("Gol/Sh_std", fontsize=14)
plt.ylabel("npxG/Sh_std", fontsize=14, rotation=90)
plt.show()

# %% [markdown]
# ### 3.2 Obtención del número de clusters (10 puntos)

# %%
def Exec_KMeans(k, X):
    
    kmeans = KMeans(n_clusters=k, random_state=42)
    y_pred = kmeans.fit_predict(X)
    
    print("Centros de los clusters: ", kmeans.cluster_centers_)
    
    plt.figure(figsize=(16, 6))
    cl = ['red', 'green', 'blue', 'yellow', 'black']
    assign = []
    for row in y_pred:
        assign.append(cl[row])
        
    plt.scatter(X[:,0], X[:,1], c=assign, s=70)
    
    plt.show()
    
    return y_pred

# %%
K=5
y_pred = Exec_KMeans(K, X)
# Out:
# Centros de los clusters:  [[ 0.24094396 -0.73852404]
#  [ 0.81316456  0.86496396]
#  [-0.45550004  0.18199685]
#  [ 3.05975814  2.37936929]
#  [-1.06906552 -1.15848518]]

# %%
# Visualizamos la inercia
kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(X)
                for k in range(1, 10)]
inertias = [model.inertia_ for model in kmeans_per_k]

plt.figure(figsize=(8, 3.5))
plt.plot(range(1, 10), inertias, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.annotate('Elbow',
             xy=(2, inertias[1]),
             xytext=(0.5, 0.7),
             textcoords='figure fraction',
             fontsize=16,
             arrowprops=dict(facecolor='black', shrink=0.1)
            )
plt.show()

# %%
# Visualizamos el sillhoute score
silhouette_scores = [silhouette_score(X, model.labels_) for model in kmeans_per_k[1:]]

plt.figure(figsize=(8, 3))
plt.plot(range(2, 10), silhouette_scores, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)

plt.show()

# %%
# Seleccionamos un número de clusters K. Cambiar K=1 por el número que consideres.
# Recomendación: hay que mirar en la inercia y el score, quizás podemos apostar por un poquito de menos score.
K=2
y_pred2 = Exec_KMeans(K, X)
y_pred3 = Exec_KMeans(3, X)
# Out:
# Centros de los clusters:  [[-0.6364474  -0.65800702]
#  [ 0.80720158  0.83454548]]
# Centros de los clusters:  [[-0.74188432 -0.85367968]
#  [ 1.8487601   1.4804442 ]
#  [ 0.24587551  0.45648734]]

# %%
plt.figure(figsize=(11, 9))

for k in (2, 3, 4, 5):
    plt.subplot(2, 2, k - 1)
    
    y_pred = kmeans_per_k[k - 1].labels_
    silhouette_coefficients = silhouette_samples(X, y_pred)

    padding = len(X) // 30
    pos = padding
    ticks = []
    for i in range(k):
        coeffs = silhouette_coefficients[y_pred == i]
        coeffs.sort()

        color = plt.cm.Spectral(i / k)
        plt.fill_betweenx(np.arange(pos, pos + len(coeffs)), 0, coeffs,
                          facecolor=color, edgecolor=color, alpha=0.7)
        ticks.append(pos + len(coeffs) // 2)
        pos += len(coeffs) + padding

    plt.gca().yaxis.set_major_locator(FixedLocator(ticks))
    plt.gca().yaxis.set_major_formatter(FixedFormatter(range(k)))
    if k in (3, 5):
        plt.ylabel("Cluster")
    
    if k in (5, 6):
        plt.gca().set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
        plt.xlabel("Silhouette Coefficient")
    else:
        plt.tick_params(labelbottom=False)

    plt.axvline(x=silhouette_scores[k - 2], color="red", linestyle="--")
    plt.title("$k={}$".format(k), fontsize=16)

plt.show()

# %% [markdown]
# ### 3.3 Visualizar los clusters (10 puntos)

# %% [markdown]
# ### No tocar la siguiente celda puesto que tiene 3 funciones auxiliares en estado final

# %%
def Exec_KMeans(k, X):
    
    kmeans = KMeans(n_clusters=k, random_state=42)
    y_pred = kmeans.fit_predict(X)
    
    print("Centros de los clusters: ", kmeans.cluster_centers_)
    
    plt.figure(figsize=(16, 6))
    cl = ['red', 'green', 'blue', 'yellow', 'black']
    assign = []
    for row in y_pred:
        assign.append(cl[row])
        
    plt.scatter(X[:,0], X[:,1], c=assign, s=70)
    
    plt.show()
    
    return y_pred

# %%
# Ejecutamos KMeans con el número de clusters (K) que hayas elegido y guardalo en una variable 'Cluster'
# en el dataset original (dt, si es tu caso)
selectedK = 3

dt['Cluster'] = Exec_KMeans(selectedK, X)
# Out:
# Centros de los clusters:  [[-0.74188432 -0.85367968]
#  [ 1.8487601   1.4804442 ]
#  [ 0.24587551  0.45648734]]

# %%
dt.sample(20)
# Out:
#                PlayerName                TeamName     Season  Gol/Sh  npxG/Sh  \
# 64          Karim Benzema          Real Madrid CF  2019-2020    0.14     0.12
# 23           Jhon Córdoba              1. FC Köln  2019-2020    0.20     0.15
# 58            Richarlison              Everton FC  2019-2020    0.14     0.10
# 62       Giovanni Simeone         Cagliari Calcio  2019-2020    0.14     0.14
# 79                 Joselu        Deportivo Alavés  2019-2020    0.12     0.12
# 45          Robin Quaison         1. FSV Mainz 05  2019-2020    0.17     0.14
# 34           Josip Ilicic             Atalanta BC  2019-2020    0.19     0.11
# 30    Alexandre Lacazette              Arsenal FC  2019-2020    0.19     0.16
# 36    Sebastian Andersson      1. FC Union Berlin  2019-2020    0.18     0.18
# 6        Francesco Caputo      US Sassuolo Calcio  2019-2020    0.26     0.20
# 89       Lautaro Martínez          Internazionale  2019-2020    0.10     0.11
# 74           Lionel Messi            FC Barcelona  2019-2020    0.13     0.10
# 92     0.08   -1.995077    -1.629351        0

# %% [markdown]
# ### Nos hemos decantado en escoger 3 clusteres en lugar de 2. En los 2 clusteres, tenemos a favor un valor más alto de Silhouette score y una diferenciación de clusteres más clara que con 3 clusteres, sin embargo en los 3 clúteres,  la diferencia de inercia con el de 2 clusteres es significante.  Y por último, en la gráfica de los volúmenes de los clusteres, cuando K=2 existe un gran volumen de datos en ambos clusteres, sin embargo existe una mayor distribución en K=3 aunque el cluster 1 no tenga tanto volumne como los otros dos.

# %% [markdown]
# # 4. Reducción de dimensionalidad - Jugador Similar a Paulo Dybala
#
# Un club de fútbol europeo, de gran presupuesto, nos ha pedido que encontremos al jugador más parecido a <strong>Paulo Dybala</strong>. Este jugador es de gran interés para dicho club, pero no es posible el traspaso y por ello necesitan ayuda para encontrar al centrocampista más parecido. Nos ofrecen un set de datos de centrocampistas de las principales ligas europeas de la temporada 2017/2018. Por lo que las métricas que nos ofrecen son de ese año. Asumen que dicha similitud que logremos sería en base a lo de ese año, pero les compensa aun así.
#
# Por lo que debemos trabajar con ese dataset para encontrar a los centrocampistas más parecidos a dicho futbolista basándonos en las métricas de ese año, es decir, 'los futbolistas más parecidos en ese año'. Con esta información, empezará el departamento de scouting a analizar más en detalle.
#
# <br>
# <strong>
#     Para seguir estos pasos, se recomienda ir paso a paso en el notebook 'Dimensionality Reduction: PCA'
# </strong>

# %% [markdown]
# ### 4.1 Estudio de los datos (5 puntos)

# %%
# Cargamos el dataset (en la carpeta data con nombre PCA)
dt = pd.read_csv('data/PCA.csv')

# %%
# Visualizar las 5 primeras muestras del dataset
dt.head(5)
# Out:
#           PlayerName  Edad  Goles  Asistencias  Tarjetas_Amarilla  \
# 0  Stanislav Lobotka    22      0            0                  2
# 1        Daniel Wass    28      4            8                  3
# 2        Pione Sisto    22      5            7                  2
# 3            Fabinho    23      7            3                  8
# 4         Rony Lopes    21     15            6                  2
#
#    Tarjetas_Roja  PasesCompletados  PasesIntentados  Pct_PasesCompletados  \
# 0              0              1858             2065                  90.0
# 1              0              1250             1667                  75.0
# 2              0               876             1091                  80.3
# 3              0              1680             1976                  85.0
# 4              0               579              841                  68.8
#
#    PasesUltTercioCampo  PasesClave  PasesCruzados  PasesCambioDeBanda   xG  \
# 0                  169          10              6                  52  0.3
# 1                  116          56             97                  63  4.4
# 2                   65          42             56                  50  3.8
# 3                  210          34              9                  65  5.5
# 4                   40          39             82                  18  9.8
#
#    npxG   xA  xG_90Min  xA_90Min
# 0   0.3  0.5      0.01      0.01
# 1   4.4  5.0      0.13      0.15
# 2   3.8  4.6      0.13      0.16
# 3   2.4  3.7      0.16      0.11
# 4   9.8  5.5      0.35      0.19

# %%
# Visualizar los tipos de dato de cada variable
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PlayerName            268 non-null    object
#  1   Edad                  268 non-null    int64
#  2   Goles                 268 non-null    int64
#  3   Asistencias           268 non-null    int64
#  4   Tarjetas_Amarilla     268 non-null    int64
#  5   Tarjetas_Roja         268 non-null    int64
#  6   PasesCompletados      268 non-null    int64
#  7   PasesIntentados       268 non-null    int64
#  8   Pct_PasesCompletados  268 non-null    float64
#  9   PasesUltTercioCampo   268 non-null    int64
#  10  PasesClave            268 non-null    int64
#  11  PasesCruzados         268 non-null    int64
#  12  PasesCambioDeBanda    268 non-null    int64
#  13  xG                    268 non-null    float64
#  14  npxG                  268 non-null    float64
#  15  xA                    268 non-null    float64
#  16  xG_90Min              268 non-null    float64
#  17  xA_90Min              268 non-null    float64
# dtypes: float64(6), int64(11), object(1)
# memory usage: 37.8+ KB

# %%
# Pasamos las métricas a una matriz X y los nombres de los jugadores a una matriz y
X, y= dt.iloc[:, 1:len(dt.columns)].values, dt[['PlayerName']].values.squeeze()

# %% [markdown]
# ### 4.2 Obtención del número de componentes (10 puntos)

# %%
# Escalamos la matriz X
X_std=StandardScaler().fit_transform(X)

# %%
# Aplicamos PCA para obtener una matriz x pero con las dimensiones (X_pca)
pca = PCA(n_components = len(dt.columns)-1)
pca.fit(X_std)
X_pca = pca.transform(X_std)

# %%
# Visualizamos las dimensiones para determinar qué número nos interesa más
print("Shape x_PCA: ", X_pca.shape)
expl = pca.explained_variance_ratio_

for x in range(0, len(dt.columns), 2):
    print("Explained Variance: " + str(x) + " components:", sum(expl[0:x]))

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Dimensions')
plt.ylabel('Explained Variance')
plt.show()
# Out:
# Shape x_PCA:  (268, 17)
# Explained Variance: 0 components: 0
# Explained Variance: 2 components: 0.6057763618759011
# Explained Variance: 4 components: 0.7913051593893251
# Explained Variance: 6 components: 0.8920389485394616
# Explained Variance: 8 components: 0.9443915679500727
# Explained Variance: 10 components: 0.9775444464822022
# Explained Variance: 12 components: 0.9903895685625353
# Explained Variance: 14 components: 0.9980209398240852
# Explained Variance: 16 components: 0.9998778607727563

# %%
# Seleccionamos el número de componentes y mostramos (head) el dataframe con las dimensiones
N_COMP = 8
columns = []

for col in range(1, N_COMP+1, 1):
    columns.append("PCA" + str(col))

dt_pca_resultado = pd.DataFrame(data=X_pca[:,0:N_COMP], columns=columns, index = y)

dt_pca_resultado.head()
# Out:
#                        PCA1      PCA2      PCA3      PCA4      PCA5      PCA6  \
# Stanislav Lobotka -4.121911  0.588617  1.185821 -2.127377  0.594480 -0.305093
# Daniel Wass        1.299715  1.721811 -1.316289 -0.317106 -0.665471 -0.244217
# Pione Sisto        1.054865 -0.075274 -0.796471 -1.182270  0.885542 -0.438043
# Fabinho           -1.189690  1.894763  1.901538 -0.432187  0.531688  1.005850
# Rony Lopes         4.503468 -1.661998  0.570938 -0.332270  0.598618  0.542238
#
#                        PCA7      PCA8
# Stanislav Lobotka -0.943728 -0.095647
# Daniel Wass       -0.479155  0.810038
# Pione Sisto        0.238301 -0.186621
# Fabinho            0.353496 -0.227902
# Rony Lopes        -0.632987  0.590453

# %% [markdown]
# ### 4.3 Matriz de correlación y listado de centrocampistas (10 puntos)

# %%
# Obtenemos la matriz de correlación (Pearson)
corr_matrix = dt_pca_resultado.T.corr(method='pearson')

# %%
# Mostramos las primeras 5 muestras (head)
# Pione Sisto               0.580995     -0.701242             -0.489732
# Fabinho                  -0.516905      0.513866             -0.221389
# Rony Lopes                0.857852     -0.843047             -0.168670
#
#                    Daniele Baselli    Rômulo    Caiuby  Michael Gregoritsch  \
# Stanislav Lobotka         0.320856 -0.380427 -0.706735            -0.385503
# Daniel Wass              -0.729747  0.724037  0.148238            -0.380100
# Pione Sisto              -0.634407 -0.180663 -0.120577             0.042194
# Fabinho                   0.197349 -0.289553 -0.748972            -0.355839
# Rony Lopes               -0.553562 -0.162993  0.315891             0.791733
#
#                    Antonín Barák  Jakub Jankto  Rodrigo De Paul  Mark Uth  \
# Stanislav Lobotka       0.375040     -0.579723        -0.669254 -0.660760
# Daniel Wass            -0.751820      0.458160         0.700164 -0.151107
# Pione Sisto             0.181522      0.863964         0.760417  0.312978
# Fabinho                 0.148782     -0.581971        -0.540659 -0.558126
# Rony Lopes              0.105602      0.562132         0.464417  0.855146
#
#                    Andrej Kramaric
# Stanislav Lobotka        -0.746492
# Daniel Wass               0.329564
# Pione Sisto               0.470377
# Fabinho                  -0.522697
# Rony Lopes                0.898926

# %% [markdown]
# ### No tocar la siguiente celda puesto que tiene 3 funciones auxiliares en estado final

# %%
def GetSimilarPlayers(PlayerName, numPlayers, corr_matrix):
    
    SimPlayers = pd.DataFrame(columns = ['PlayerName', 'Similar Player', 'Correlation Factor'])

    i = 0
    for i in range(0, numPlayers):
        row = corr_matrix.loc[corr_matrix.index == PlayerName].squeeze()

        SimPlayers.at[i, 'PlayerName'] = PlayerName
        SimPlayers.at[i, 'Similar Player'] = row.nlargest(i+2).sort_values(ascending=True).index[0]
        SimPlayers.at[i, 'Correlation Factor'] = row.nlargest(i+2).sort_values(ascending=True)[0]

        i = i+1
    
    return SimPlayers

# %%
# Obtenemos los 10 centrocampistas más similares que nos piden en base a las métricas que nos han ofrecido.
# Nota, el nombre del jugador del cual hay que buscar sus similares es Paulo Dybala.
PlayerName = 'Paulo Dybala'
NumPlayers = 10

df_correlatedPlayers = GetSimilarPlayers(PlayerName, NumPlayers, corr_matrix)

df_correlatedPlayers
# Out:
#      PlayerName    Similar Player Correlation Factor
# 0  Paulo Dybala     Mohamed Salah           0.905031
# 1  Paulo Dybala      Lionel Messi           0.886883
# 2  Paulo Dybala    Thorgan Hazard           0.871955
# 3  Paulo Dybala  Karl Toko Ekambi           0.854663
# 4  Paulo Dybala     Memphis Depay             0.8528
# 5  Paulo Dybala   Bryan Cristante           0.846316
# 6  Paulo Dybala   Andrej Kramaric           0.807547
# 7  Paulo Dybala     Son Heung-min            0.78274
# 8  Paulo Dybala      Josip Ilicic            0.78112
# 9  Paulo Dybala      Nicolas Pépé            0.76742

# %% [markdown]
# ### Entendemos que cuando se piden los 10 centrocampistas más similares es que todo el dataset es sobre centrocampistas y de ahí sacamos los centrocampistas que vemos en la celda anterior. En cuanto al algoritmo, se acerca a algunos jugadores que conocemos que son similares, pero con más datos sobre de cada jugador posiblemente estas similitudes fueran mucho mejores
